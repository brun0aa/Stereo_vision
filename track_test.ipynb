# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.pt')  # load an official detection model
model = YOLO('yolov8n-seg.pt')  # load an official segmentation model

# Track with the model
results = model.track(source="teste_video.avi",persist = True, show=True) 
#results = model.track(source="https://www.youtube.com/watch?v=ExOmEig2uw4", show=True, tracker="bytetrack.yaml")
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/2) /home/sleepkat/teste_video.avi: 480x640 1 person, 1 chair, 64.0ms
# video 1/1 (2/2) /home/sleepkat/teste_video.avi: 480x640 1 person, 1 chair, 61.9ms
# Speed: 2.9ms preprocess, 62.9ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)

# %%
import cv2
import numpy as np
import glob

frameSize = (640, 480)

out = cv2.VideoWriter('teste_video.avi',cv2.VideoWriter_fourcc(*'DIVX'), 24, frameSize)

for filename in glob.glob('teste_track/*.jpg'):
    img = cv2.imread(filename)
    out.write(img)

out.release()

# %% [markdown]
# from ultralytics import YOLO
#
# # Load a model
# model = YOLO('yolov8n.pt')  # load an official detection model
# model = YOLO('yolov8n-seg.pt')  # load an official segmentation model
#
# # Track with the model
# results = model.track(source="video_teste.mkv", show=True)
# #results = model.track(source="https://www.youtube.com/watch?v=ExOmEig2uw4", show=True, tracker="bytetrack.yaml")

# %%
import numpy as np
import cv2 as cv

fourcc = cv.VideoWriter_fourcc(*'XVID')

cap = cv.VideoCapture('video_teste.mkv')
res_L = cv.VideoWriter('res_L.avi', fourcc, 20.0, (640, 480))
res_R= cv.VideoWriter('res_R.avi', fourcc, 20.0, (640, 480))
saida= cv.VideoWriter('saida_L_R.avi', fourcc, 20.0, (640, 480))
while cap.isOpened():
    ret, frame = cap.read()
    # if frame is read correctly ret is True
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    frameL= frame[0:480,0:640]
    frameR =frame[0:480,640:1280]
    
    saida.write(frameL)
    saida.write(frameR)
    
    grayL = cv.cvtColor(frameL,cv.COLOR_BGR2GRAY)
    grayR=cv.cvtColor(frameR,cv.COLOR_BGR2GRAY)
    
    cv.imshow('frame R gray',grayR)
    cv.imshow('frame L gray',grayL)
    
    res_L.write(frameL)
    res_R.write(frameR)
    
    if cv.waitKey(1) == ord('q'):
        break
cap.release()
cv.destroyAllWindows()
res_L.release()
res_R.release()
saida.release()
# Out:
# Can't receive frame (stream end?). Exiting ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.pt')  # load an official detection model
model = YOLO('yolov8n-seg.pt')  # load an official segmentation model

# Track with the model
#results = model.track(source="saida_L_R.avi", show=True) 
results = model.track(source="saida_L_R.avi",persist=True, save=True, show=True)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/542) /home/sleepkat/saida_L_R.avi: 480x640 1 vase, 64.4ms
# video 1/1 (2/542) /home/sleepkat/saida_L_R.avi: 480x640 1 vase, 61.6ms
# video 1/1 (3/542) /home/sleepkat/saida_L_R.avi: 480x640 1 vase, 61.9ms
# video 1/1 (4/542) /home/sleepkat/saida_L_R.avi: 480x640 1 vase, 61.6ms
# video 1/1 (5/542) /home/sleepkat/saida_L_R.avi: 480x640 1 vase, 61.8ms
# video 1/1 (6/542) /home/sleepkat/saida_L_R.avi: 480x640 1 vase, 61.7ms
# ...

# %%
from ultralytics import YOLO
import cv2 as cv
cap = cv.VideoCapture('saida_L_R.avi')
model = YOLO('yolov8n.pt')  # load an official detection model
box_a = 0
xL = [0] * 5
xR = [0] * 5
old_xL = [0] * 5
old_xR = [0] * 5
salva = []
i = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break
    results = model.track(frame, persist=True, show=True)
    boxes = results[0].boxes.xyxy.cpu().numpy().astype(int)
    ids = results[0].boxes.id.cpu().numpy().astype(int)
    
    print(f"teste: {old_xR[0]}")
    
    for box, id in zip(boxes, ids):
        
        print(f"teste1: {old_xR[0]}")
        old_xL[id-1] = xL[id-1]
        old_xR[id-1] = xR[id-1]
        xL[id-1] = box[0]
        xR[id-1] = box[1]
      
        print(f"teste2: {old_xR[0]}")
        
        d_pixel = abs(old_xL[id-1] - xL[id-1])
        
        if d_pixel == 0:
            dist = 0
        else:
            dist = 13903.92/d_pixel
            
        cv.rectangle(frame, (box[0], box[1]), (box[2], box[3]), (0, 255, 0), 2)
        cv.putText(
            frame,
            f"Id:{id}",
            (box[0], box[1]),
            cv.FONT_HERSHEY_SIMPLEX,
            1,
            (0, 0, 255),
            2,
            )
        cv.putText(
            frame,
            f"D:{dist:.1f}cm",
            (box[0]+70, box[1]),
            cv.FONT_HERSHEY_SIMPLEX,
            1,
            (0, 0, 255),
            2,
            )
        cv.imshow("frame", frame)
        if cv.waitKey(1) & 0xFF == ord("q"):
            break
# Out:
# 0: 480x640 1 vase, 48.6ms
# Speed: 7.1ms preprocess, 48.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vase, 47.2ms
# Speed: 3.1ms preprocess, 47.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vase, 47.8ms
# Speed: 9.3ms preprocess, 47.8ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# teste: 0
# teste1: 0
# teste2: 0
# teste: 0
# teste1: 0
# teste2: 99
# teste: 99
# teste1: 99
# teste2: 101
# 0: 480x640 1 toilet, 47.3ms
# Speed: 3.2ms preprocess, 47.3ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 vase, 47.7ms
# Speed: 3.3ms preprocess, 47.7ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 48.9ms
# Speed: 4.8ms preprocess, 48.9ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
# teste: 101
# teste1: 101
# teste2: 98
# teste: 98
# teste1: 98
# teste2: 99
# teste: 99
# teste1: 99
# teste2: 98
# ...

# %%
#distancia incial de 122cm para o objeto mais próximo (distante 30cm do outro objeto)
#distancia final de aproximadamente 61cm para o objeto mais próximo
